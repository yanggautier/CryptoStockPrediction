# %% [markdown]
# ## pycoingecko

# %% [markdown]
# 50 appels/minute gratuit, données historiques excellentes

# %%
# !pip install pycoingecko

# %%
from pycoingecko import CoinGeckoAPI  

cg = CoinGeckoAPI()
data = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days=365)

# %%
data
# Out:
# {'prices': [[1731369600000, 88637.42000322911],
#   [1731456000000, 88264.59974582895],
#   [1731542400000, 90488.10007497849],
#   [1731628800000, 87407.51273710128],
#   [1731715200000, 90947.97509443703],
#   [1731801600000, 90606.45489380708],
#   [1731888000000, 89841.47194135105],
#   [1731974400000, 90534.62459650292],
#   [1732060800000, 92251.65240738312],
#   [1732147200000, 94217.02229634205],
#   [1732233600000, 98509.11859102432],
#   [1732320000000, 98927.49494553401],
#   [1732406400000, 97679.46381643033],
#   [1732492800000, 98015.9355289458],
#   [1732579200000, 93004.70093103287],
#   [1732665600000, 91931.83077291827],
#   [1732752000000, 95981.18057210564],
#   [1732838400000, 95661.59595817851],
#   [1732924800000, 97453.2473451042],
#   [1733011200000, 96513.14234698225],
#   [1733097600000, 97311.70719084324],
#   [1733184000000, 95833.1362300365],
#   [1733270400000, 96031.63097759831],
#   [1733356800000, 98881.4694561823],
# ...

# %% [markdown]
# ## Binance

# %% [markdown]
# Gratuit, très complet, données minute/heure/jour

# %%
#!pip install ccxt
# Out:
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/jupyter-1.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/jupyter-1.0.0.dist-info due to invalid metadata entry 'name'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 25.9 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.4 MB/s eta 0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.0/497.0 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 5.5 MB/s eta 0:00:00
# ...

# %%
import ccxt
exchange = ccxt.binance()
ohlcv = exchange.fetch_ohlcv('BTC/USDT', '1d', limit=1000)

# %%
ohlcv
# Out:
# [[1676505600000, 24322.87, 25250.0, 23505.25, 23517.72, 450080.68366],
#  [1676592000000, 23517.72, 25021.11, 23339.37, 24569.97, 496813.21376],
#  [1676678400000, 24568.24, 24877.0, 24430.0, 24631.95, 216917.25213],
#  [1676764800000, 24632.05, 25192.0, 24192.57, 24271.76, 300395.99542],
#  [1676851200000, 24272.51, 25121.23, 23840.83, 24842.2, 346938.56997],
#  [1676937600000, 24843.89, 25250.0, 24148.34, 24452.16, 376000.82868],
#  [1677024000000, 24450.67, 24476.05, 23574.69, 24182.21, 379425.75365],
#  [1677110400000, 24182.21, 24599.59, 23608.0, 23940.2, 398400.45437],
#  [1677196800000, 23940.2, 24132.35, 22841.19, 23185.29, 343582.57453],
#  [1677283200000, 23184.04, 23219.13, 22722.0, 23157.07, 191311.8101],
#  [1677369600000, 23157.07, 23689.99, 23059.18, 23554.85, 202323.73623],
#  [1677456000000, 23554.85, 23897.99, 23106.77, 23492.09, 283706.0859],
#  [1677542400000, 23492.09, 23600.0, 23020.97, 23141.57, 264140.99894],
# ...

# %% [markdown]
# ## Yahoo Finance

# %% [markdown]
# Via yfinance pour BTC-USD, ETH-USD

# %%
#!pip install yfinance

# %%
df = yf.download(
    tickers = "BTC-USD",
    period = "12mo",
    interval = "1d"
)
# Out:
# /var/folders/b8/_p_1v95j6ql648xwdw382p9h0000gn/T/ipykernel_2955/220456127.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2024-11-11   88701.484375   89604.500000   80283.250000   80471.414062
# 2024-11-12   87955.812500   89956.882812   85155.109375   88705.562500
# 2024-11-13   90584.164062   93434.351562   86256.929688   87929.968750
# 2024-11-14   87250.429688   91765.218750   86682.812500   90574.882812
# 2024-11-15   91066.007812   91868.742188   87124.898438   87284.179688
# ...                   ...            ...            ...            ...
# 2025-11-07  103372.406250  104052.914062   99257.054688  101286.242188
# 2025-11-08  102282.117188  103373.562500  101458.039062  103371.703125
# 2025-11-09  104719.640625  105418.367188  101468.875000  102278.984375
# 2025-11-10  105996.593750  106564.695312  104350.648438  104723.773438
# 2025-11-11  103300.429688  107244.687500  102962.585938  105986.179688
#
# Price             Volume
# ...

# %% [markdown]
# ## Sentiment Analyse

# %% [markdown]
# ### Tweet

# %%
pip uninstall snscrape -y
# Out:
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/jupyter-1.0.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/anaconda3/lib/python3.11/site-packages/jupyter-1.0.0.dist-info due to invalid metadata entry 'name'
# Found existing installation: snscrape 0.7.0.20230622
# Uninstalling snscrape-0.7.0.20230622:
#   Successfully uninstalled snscrape-0.7.0.20230622
# Note: you may need to restart the kernel to use updated packages.

# %%
GetOldTweets3

# %% [markdown]
# ## Trend

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl='fr-FR', tz=360)
pytrends.build_payload(['bitcoin'], timeframe='today 12-m')
data = pytrends.interest_over_time()
